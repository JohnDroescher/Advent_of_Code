# %%
print('pull/push successful!')

# just another note to show something
# Out:
# pull/push successful!

# %%
print("I've made a change to my document!")
# Out:
# I've made a change to my document!

# %%
# another cell added
