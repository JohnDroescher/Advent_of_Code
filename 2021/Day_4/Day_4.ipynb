# %%
import pandas as pd
import numpy as np

# Load numbers to be called:
boards = pd.DataFrame(np.genfromtxt('input.txt', skip_header=1)).astype(int)
call_nums = list(pd.read_csv('input.txt', header=None).iloc[0].astype(int))

# %%
# First we check for the first 5 numbers in all rows
for i in range(0, boards.shape[0], 5):
    print(call_nums[:5] in boards[i:i+5].values)
    print(boards[i:i+5])
    print(call_nums[:5])

# for n in call_nums[6:10]:
#     print(n)
#     for i in range(0, boards.shape[0], 5):
#         print(n in boards[i:i+5].values)
# Out:
# False
#     0   1   2   3   4
# 0  91   5  64  81  34
# 1  15  99  31  63  65
# 2  45  39  54  93  83
# 3  51  14  23  86  32
# 4  19  22  16  13   3
# [73, 42, 95, 35, 13]
# False
#     0   1   2   3   4
# 5  20  83  38  85  70
# 6  69  12  14  26  84
# 7  19  76  45  78  99
# 8  22  80  90  33  46
# 9  75  31  21   6  28
# [73, 42, 95, 35, 13]
# False
#      0   1   2   3   4
# 10  22  52  65  75   2
# 11  91  12  45  18  94
# 12  38  66  85  39   1
# 13  24  36  55  74   3
# 14  89  14  79  99  48
# [73, 42, 95, 35, 13]
# True
#      0   1   2   3   4
# 15  19  58  95  22   6
# 16  48  28  57  30  72
# 17  12  67  15  37  18
# 18  33   1  49  90  60
# 19  35  41  47  11  84
# [73, 42, 95, 35, 13]
# False
#      0   1   2   3   4
# 20  89  27  65  68  19
# 21  38  83  21  81  91
# 22  67  61  87  30  10
# 23  36  45  66  56   4
# 24  82  71  44  96  90
# [73, 42, 95, 35, 13]
# False
#      0   1   2   3   4
# 25  29  84  40  62  92
# 26  69  39   2   1  56
# 27   6  20  27  97  54
# ...
